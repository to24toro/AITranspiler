# %%
from utils import plot_graph, load_graph_from_npy
from graph_to_ansatz import GraphAnsatzConverter

# %%
g = load_graph_from_npy("graphs/adj_matrix_1.npy")
plot_graph(g)

# %%
converter = GraphAnsatzConverter(g)
print("Cost Function Hamiltonian:", converter.hamiltonian)
# Out:
# Cost Function Hamiltonian: SparsePauliOp(['IIIZIZ', 'IZIIIZ', 'ZIIIIZ', 'IIZIZI', 'IZIIZI', 'ZIIIZI', 'IIZZII', 'ZIIZII', 'IZZIII'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])

# %%
ansatz = converter.build_qaoa_ansatz(reps=1)
ansatz.decompose().decompose().draw(output="mpl")
